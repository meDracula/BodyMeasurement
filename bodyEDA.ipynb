# %%
import pandas as pd
female_file = "female.csv"
male_file = "male.csv"

# %%
female_data = pd.read_csv(female_file)
male_data = pd.read_csv(male_file)

# %%
male_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
male_data.tail()
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 4077                    312                 216          1263
# 4078                    336                 234          1346
# 4079                    313                 227          1280
# 4080                    327                 223          1314
# 4081                    358                 226          1408
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 4077                      228               193                384
# 4078                      253               196                428
# ...

# %%
female_data.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
female_data.tail()
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 1981      29501                             285            1392
# 1982      29502                             262            1324
# 1983      29503                             260            1334
# 1984      29511                             205            1293
# 1985     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 1981                    335                 223          1297
# 1982                    301                 202          1204
# 1983                    318                 213          1259
# 1984                    302                 199          1207
# 1985                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 1981                      252               196                368
# 1982                      236               181                378
# ...

# %%
male = [x for x in male_data.columns]
female = [x for x in female_data.columns]
print("Male:",male, len(male), '\n')
print("Female:", female, len(female))
# Out:
# Male: ['subjectid', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength
# ...

# %%
print(male_data['stature'].describe(),any(male_data['Heightin'].isnull()))
print(male_data['weightkg'].describe(),any(male_data['weightkg'].isnull()))
# Out:
# count    4082.000000
# mean     1756.214601
# std        68.550788
# min      1491.000000
# 25%      1710.000000
# 50%      1755.000000
# 75%      1802.000000
# max      1993.000000
# Name: stature, dtype: float64 False
# count    4082.000000
# mean      855.239588
# std       142.206992
# min       393.000000
# 25%       756.000000
# 50%       846.000000
# 75%       944.000000
# max      1442.000000
# Name: weightkg, dtype: float64 False

# %% [markdown]
# ## Overview
# To analys [K-Nearest Neighbor]
#
# * Keep:
#     - kvinnor:
#         - chestcircumference (BUST)
#         - waistcircumference  (WAIST)
#     - Men:
#         - chestcircumference (Chest)
#         - waistcircumference (Waist)
#
#
# * Delete:
#     - 'SubjectId',
#     - 'abdominalextensiondepthsitting',
#     - 'acromialheight',
#     - 'acromionradialelength',
#     - 'anklecircumference',
#     - 'axillaheight',
#     - 'balloffootcircumference',
#     - 'balloffootlength',
#     - 'biacromialbreadth',
#     - 'bicepscircumferenceflexed',
#     - 'bicristalbreadth',
#     - 'bideltoidbreadth',
#     - 'bimalleolarbreadth',
#     - 'bitragionchinarc',
#     - 'bitragionsubmandibulararc',
#     - 'bizygomaticbreadth',
#     - 'buttockcircumference',
#     - 'buttockdepth',
#     - 'buttockheight',
#     - 'buttockkneelength',
#     - 'buttockpopliteallength',
#     - 'calfcircumference',
#     - 'cervicaleheight',
#     - 'chestbreadth',
#     - 'chestcircumference',
#     - 'chestdepth',
#     - 'chestheight',
#     - 'crotchheight',
#     - 'crotchlengthomphalion',
#     - 'crotchlengthposterioromphalion',
#     - 'earbreadth',
#     - 'earlength',
#     - 'earprotrusion',
#     - 'elbowrestheight',
#     - 'eyeheightsitting',
#     - 'footbreadthhorizontal',
#     - 'footlength',
#     - 'forearmcenterofgriplength',
#     - 'forearmcircumferenceflexed',
#     - 'forearmforearmbreadth',
#     - 'forearmhandlength',
#     - 'functionalleglength',
#     - 'handbreadth',
#     - 'handcircumference',
#     - 'handlength',
#     - 'headbreadth',
#     - 'headcircumference',
#     - 'headlength',
#     - 'heelanklecircumference',
#     - 'heelbreadth',
#     - 'hipbreadth',
#     - 'hipbreadthsitting',
#     - 'iliocristaleheight',
#     - 'interpupillarybreadth',
#     - 'interscyei',
#     - 'interscyeii',
#     - 'kneeheightmidpatella',
#     - 'kneeheightsitting',
#     - 'lateralfemoralepicondyleheight',
#     - 'lateralmalleolusheight',
#     - 'lowerthighcircumference',
#     - 'mentonsellionlength',
#     - 'neckcircumference',
#     - 'neckcircumferencebase',
#     - 'overheadfingertipreachsitting',
#     - 'palmlength',
#     - 'poplitealheight',
#     - 'radialestylionlength',
#     - 'shouldercircumference',
#     - 'shoulderelbowlength',
#     - 'shoulderlength',
#     - 'sittingheight',
#     - 'sleevelengthspinewrist',
#     - 'sleeveoutseam',
#     - 'span',
#     - 'stature',
#     - 'suprasternaleheight',
#     - 'tenthribheight',
#     - 'thighcircumference',
#     - 'thighclearance',
#     - 'thumbtipreach',
#     - 'tibialheight',
#     - 'tragiontopofhead',
#     - 'trochanterionheight',
#     - 'verticaltrunkcircumferenceusa',
#     - 'waistbacklength',
#     - 'waistbreadth',
#     - 'waistcircumference',
#     - 'waistdepth',
#     - 'waistfrontlengthsitting',
#     - 'waistheightomphalion',
#     - 'weightkg',
#     - 'wristcircumference',
#     - 'wristheight',
#     - 'Gender',
#     - 'Date',
#     - 'Installation',
#     - 'Component',
#     - 'Branch',
#     - 'PrimaryMOS',
#     - 'SubjectsBirthLocation',
#     - 'SubjectNumericRace',
#     - 'Ethnicity',
#     - 'DODRace',
#     - 'Age',
#     - 'Heightin',
#     - 'Weightlbs',
#     - 'WritingPreference'

# %%
def div_conversion(df, column, div):
    return df[column].apply(lambda x: x/div)

# %%
#chestcircumference
male_data['chestcircumference'] = div_conversion(male_data, 'chestcircumference', 10) # Convert from mm to cm
#waistcircumference
male_data['waistcircumference'] = div_conversion(male_data, 'waistcircumference', 10) # Convert from mm to cm

# %%
print(male_data['chestcircumference'].describe(),any(male_data['chestcircumference'].isnull()))
print(male_data['waistcircumference'].describe(),any(male_data['waistcircumference'].isnull()))

print(female_data['chestcircumference'].describe(),any(male_data['chestcircumference'].isnull()))
print(female_data['waistcircumference'].describe(),any(male_data['waistcircumference'].isnull()))
# Out:
# count    4082.000000
# mean      105.870554
# std         8.743527
# min        77.400000
# 25%        99.600000
# 50%       105.600000
# 75%       111.700000
# max       146.900000
# Name: chestcircumference, dtype: float64 False
# count    4082.000000
# mean       94.057741
# std        11.170587
# min        64.800000
# 25%        85.700000
# 50%        93.700000
# 75%       101.600000
# max       137.900000
# Name: waistcircumference, dtype: float64 False
# count    1986.000000
# mean      946.858006
# std        82.699115
# min       695.000000
# 25%       889.000000
# 50%       940.000000
# 75%       999.000000
# max      1266.000000
# Name: chestcircumference, dtype: float64 False
# count    1986.000000
# mean      860.905337
# std        99.931771
# min       611.000000
# 25%       790.000000
# 50%       852.000000
# 75%       925.000000
# max      1334.000000
# Name: waistcircumference, dtype: float64 False

# %%
print(male_data['chestcircumference'], end='\n\n')
print(male_data['waistcircumference'])
# Out:
# 0       1074
# 1       1021
# 2       1120
# 3       1114
# 4       1048
#         ...
# 4077     954
# 4078    1072
# 4079    1045
# 4080     984
# 4081    1144
# Name: chestcircumference, Length: 4082, dtype: int64
#
# 0        933
# 1        870
# 2        964
# 3        857
# 4        868
#         ...
# 4077     816
# 4078     978
# 4079     991
# 4080     783
# 4081    1080
# Name: waistcircumference, Length: 4082, dtype: int64

# %%
def create_sample(df, gender, columns: list, sample_size):
        [list(df.columns).index(column) for column in columns]
        df = df.iloc[:sample_size, [list(df.columns).index(column) for column in columns]].copy()
        df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

def backup_sample(df, gender, sample_size):
    df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

# %% [markdown]
# # T-Shirt sizes
# T-shirt Size Chart by Body Measurement.
# Male T-shirt Size Chart by Body Measurement, <br>
# CM: SIZE WAIST CHEST <br>
# XXS 69-70 cm 74-75 cm <br>
# XS 71-76 cm 76-85 cm <br>
# S 77-80 cm 86-96 cm <br>
# M 81-84 cm 97-106 cm <br>
# L 85-90 cm 107-112 cm <br>
# XL 91-101 cm 116-121 cm <br>
# XXL 102-111 cm 122-127 cm <br>
# 3XL 112-122 cm 128-132 cm <br>
#
# Female EU SIZE INT. WAIST CHEST<br>
# XXS 54-57 cm 70-74 cm <br>
# XS 58-66 cm 75-81 cm<br>
# S 67-71 cm 82-88 cm<br>
# M 72-80 cm 89-95 cm<br>
# L 81-92 cm 96-105 cm <br>
# XL 93-100 cm 106-115 cm<br>
# XXL 101-104 cm 116-122 cm

# %%
men_sizes = {"XXS": [(69, 70), (70, 74)], "XS": [(71, 76), (76, 85)], "S": [(77, 80), (86, 96)], "M": [(81, 84), (97, 106)], "L": [(85, 90), (107, 112)], "XL": [(91, 101), (116, 121)], "XXL": [(102, 111), (122, 127)], "3XL": [(112, 122), (128, 132)]}
female_sizes = {"XSS": [(54, 57)], "XS": [(58, 66), (75,81)], "S": [(67, 71), (82, 88)], "M": [(72, 80), (89, 95)], "L": [(81, 92), (96, 105)], "XL": [(93, 100), (106, 115)], "XXL": [(101, 104), (116, 122)]}

# %%
def categories_by_size(df, sizes):
    cloth_sizes = []
    for row in range(df.shape[0]):
        print(row)
        key_found = False
        for key in sizes:
            for i, col in enumerate(df):
                print(f"Measure {i}:", sizes[key][i][0], df[col][row], sizes[key][i][1], sizes[key][i][0] < df[col][row] < sizes[key][i][1])
                if sizes[key][i][0] < df[col][row] < sizes[key][i][1]:
                    cloth_sizes.append(key)
                    key_found = True
                    break
            if key_found:
                break
            
    print(cloth_sizes, len(cloth_sizes))
    return df.assign(cloth_size=cloth_sizes)

# %%
create_sample(male_data, 'male', ['chestcircumference', 'waistcircumference'], 100)
df = pd.read_csv('male_sample100.csv')

# %%
print(df.shape[0])
# Out:
# 100

# %%
categories_by_size(df, men_sizes)
# Out:
# 0
# Measure 0: 69 107.4 70 False
# Measure 1: 70 93.3 74 False
# Measure 0: 71 107.4 76 False
# Measure 1: 76 93.3 85 False
# Measure 0: 77 107.4 80 False
# Measure 1: 86 93.3 96 True
# 1
# Measure 0: 69 102.1 70 False
# Measure 1: 70 87.0 74 False
# Measure 0: 71 102.1 76 False
# Measure 1: 76 87.0 85 False
# Measure 0: 77 102.1 80 False
# Measure 1: 86 87.0 96 True
# 2
# Measure 0: 69 112.0 70 False
# Measure 1: 70 96.4 74 False
# Measure 0: 71 112.0 76 False
# Measure 1: 76 96.4 85 False
# Measure 0: 77 112.0 80 False
# Measure 1: 86 96.4 96 False
# Measure 0: 81 112.0 84 False
# Measure 1: 97 96.4 106 False
# Measure 0: 85 112.0 90 False
# Measure 1: 107 96.4 112 False
# Measure 0: 91 112.0 101 False
# Measure 1: 116 96.4 121 False
# Measure 0: 102 112.0 111 False
# Measure 1: 122 96.4 127 False
# Measure 0: 112 112.0 122 False
# Measure 1: 128 96.4 132 False
# 3
# Measure 0: 69 111.4 70 False
# Measure 1: 70 85.7 74 False
# Measure 0: 71 111.4 76 False
# ...

# %%
print(df.columns, '\n')
print(df.count())
# Out:
# Index(['chestcircumference', 'waistcircumference'], dtype='object')
#
# chestcircumference    100
# waistcircumference    100
# dtype: int64

# %%
def k_nearest_neighbor(df, P, k):
    def vec_abs(vec):
        return sqrt(sum([unit**2 for unit in vec]))
    
    def compute_vec(*args):
        dim = 2
        vectors = [[args[index][row] - args[index-1][row] for row in range(dim)] for index in range(1, len(args))]
        vector = [sum([vec[col] for vec in vectors]) for col in range(dim)] if len(vectors) > 1 else vectors[0]
        return zip(args[0], vector) if len(args) > 2 else zip(args[0], args[1])

    x, y = df.columns
    x_max, y_max = df.count()

    for i in range(0, x_max):
        #P = [df[x][i], df[y][i]]
        points = 0
        while points < y_max:
            
            points += 1

    return 0

# %%
pd.plotting.scatter_matrix(df, diagonal="kde")
# Out:
# array([[<AxesSubplot:xlabel='chestcircumference', ylabel='chestcircumference'>,
#         <AxesSubplot:xlabel='waistcircumference', ylabel='chestcircumference'>],
#        [<AxesSubplot:xlabel='chestcircumference', ylabel='waistcircumference'>,
#         <AxesSubplot:xlabel='waistcircumference', ylabel='waistcircumference'>]],
#       dtype=object)

# %%
df.corr()
# Out:
#                     chestcircumference  waistcircumference
# chestcircumference            1.000000            0.884788
# waistcircumference            0.884788            1.000000

# %%
df.size
# Out:
# 200
