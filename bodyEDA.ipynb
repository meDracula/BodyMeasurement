# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt
female_file = "female.csv"
male_file = "male.csv"

# %%
female_data = pd.read_csv(female_file)
male_data = pd.read_csv(male_file)

# %%
male_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
male_data.tail()
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 4077                    312                 216          1263
# 4078                    336                 234          1346
# 4079                    313                 227          1280
# 4080                    327                 223          1314
# 4081                    358                 226          1408
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 4077                      228               193                384
# 4078                      253               196                428
# ...

# %%
female_data.head()
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 1981      29501                             285            1392
# 1982      29502                             262            1324
# 1983      29503                             260            1334
# 1984      29511                             205            1293
# 1985     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 1981                    335                 223          1297
# 1982                    301                 202          1204
# 1983                    318                 213          1259
# 1984                    302                 199          1207
# 1985                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 1981                      252               196                368
# 1982                      236               181                378
# ...

# %%
female_data.tail()
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 1981      29501                             285            1392
# 1982      29502                             262            1324
# 1983      29503                             260            1334
# 1984      29511                             205            1293
# 1985     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 1981                    335                 223          1297
# 1982                    301                 202          1204
# 1983                    318                 213          1259
# 1984                    302                 199          1207
# 1985                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 1981                      252               196                368
# 1982                      236               181                378
# ...

# %%
male = [x for x in male_data.columns]
female = [x for x in female_data.columns]
print("Male:\n",male, "\nColumns lenght:", len(male), '\n')
print("Female:\n", female, "\nColumn: lenght:", len(female))
# Out:
# Male:
# ...

# %% [markdown]
# ## Overview
# To find the right clothing size by amount of given measurement that will yield the correct size.
# In order to accomplish this a set of measurement will need to chosen and the reset discarded.
# The axis(measurement) that will be choosen are:
# * Keep:
#     - Women:
#         - chestcircumference (BUST)
#         - waistcircumference  (WAIST)
#     - Men:
#         - chestcircumference (Chest)
#         - waistcircumference (Waist)
#
# The rest of the measurement of the dataset will be discarded.
# The chosen measurement once polished and then classified will be the training data for k nearest neighbor algorithm.

# %%
print("Male chestcircumference\n", male_data['chestcircumference'].describe(), "\nNull values:\t", any(male_data['chestcircumference'].isnull()),"\n")
print("Male waistcircumference\n", male_data['waistcircumference'].describe(), "\nNull values:\t", any(male_data['waistcircumference'].isnull()))

print("Female chestcircumference\n", female_data['chestcircumference'].describe(), "\nNull values:\t", any(female_data['chestcircumference'].isnull()),"\n")
print("Female waistcircumference\n", female_data['waistcircumference'].describe(), "\nNull values:\t", any(female_data['waistcircumference'].isnull()))
# Out:
# Male chestcircumference
#  count    4082.000000
# mean     1058.705537
# std        87.435272
# min       774.000000
# 25%       996.000000
# 50%      1056.000000
# 75%      1117.000000
# max      1469.000000
# Name: chestcircumference, dtype: float64
# Null values:	 False
#
# Male waistcircumference
#  count    4082.000000
# mean      940.577413
# std       111.705875
# min       648.000000
# 25%       857.000000
# 50%       937.000000
# 75%      1016.000000
# max      1379.000000
# Name: waistcircumference, dtype: float64
# Null values:	 False
# Female chestcircumference
#  count    1986.000000
# mean      946.858006
# std        82.699115
# min       695.000000
# 25%       889.000000
# 50%       940.000000
# 75%       999.000000
# max      1266.000000
# Name: chestcircumference, dtype: float64
# Null values:	 False
#
# Female waistcircumference
#  count    1986.000000
# mean      860.905337
# std        99.931771
# min       611.000000
# 25%       790.000000
# ...

# %%
def div_conversion(df, column, div):
    return df[column].apply(lambda x: x/div)

# %%
# Male Dataset
#chestcircumference
male_data['chestcircumference'] = div_conversion(male_data, 'chestcircumference', 10) # Convert from mm to cm
#waistcircumference
male_data['waistcircumference'] = div_conversion(male_data, 'waistcircumference', 10) # Convert from mm to cm

# Female Dataset
#chestcircumference
female_data['chestcircumference'] = div_conversion(female_data, 'chestcircumference', 10) # Convert from mm to cm
#waistcircumference
female_data['waistcircumference'] = div_conversion(female_data, 'waistcircumference', 10) # Convert from mm to cm

# %%
print("="*5 + " Male " + "="*5)
print(male_data['chestcircumference'], end='\n\n')
print(male_data['waistcircumference'])
print("="*5 + " Female " + "="*5)
print(female_data['chestcircumference'], end='\n\n')
print(female_data['waistcircumference'])
# Out:
# ===== Male =====
# 0       107.4
# 1       102.1
# 2       112.0
# 3       111.4
# 4       104.8
#         ...
# 4077     95.4
# 4078    107.2
# 4079    104.5
# 4080     98.4
# 4081    114.4
# Name: chestcircumference, Length: 4082, dtype: float64
#
# 0        93.3
# 1        87.0
# 2        96.4
# 3        85.7
# 4        86.8
#         ...
# 4077     81.6
# 4078     97.8
# 4079     99.1
# 4080     78.3
# 4081    108.0
# Name: waistcircumference, Length: 4082, dtype: float64
# ===== Female =====
# 0        92.2
# 1        83.9
# 2        87.4
# 3       100.8
# 4       108.9
#         ...
# 1981    108.2
# 1982    101.6
# 1983    109.3
# 1984     92.2
# 1985     90.2
# Name: chestcircumference, Length: 1986, dtype: float64
#
# 0        85.0
# 1        70.8
# 2        72.7
# 3        92.3
# 4       116.3
#         ...
# 1981    104.3
# 1982     97.1
# 1983     98.2
# 1984     83.7
# 1985     89.1
# Name: waistcircumference, Length: 1986, dtype: float64

# %%
def create_sample(df, gender, columns: list, sample_size):
        [list(df.columns).index(column) for column in columns]
        df = df.iloc[:sample_size, [list(df.columns).index(column) for column in columns]].copy()
        df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

def backup_sample(df, gender, sample_size):
    df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

# %%
create_sample(male_data, 'male', ['chestcircumference', 'waistcircumference'], 100)
create_sample(female_data, 'female', ['chestcircumference', 'waistcircumference'], 100)

# %% [markdown]
# # T-Shirt sizes
# T-shirt Size Chart by Body Measurement.
# Male T-shirt Size Chart by Body Measurement, <br>
# CM: SIZE WAIST CHEST <br>
# XXS 69-71 cm 74-76 cm <br>
# XS 71-77 cm 76-86 cm <br>
# S 77-81 cm 86-97 cm <br>
# M 81-85 cm 97-107 cm <br>
# L 85-91 cm 107-116 cm <br>
# XL 91-102 cm 116-122 cm <br>
# XXL 102-112 cm 122-128 cm <br>
# 3XL 112-122 cm 128-132 cm <br>
#
# Female EU SIZE INT. WAIST CHEST<br>
# XXS 54-58 cm 70-75 cm <br>
# XS 58-67 cm 75-82 cm<br>
# S 67-72 cm 82-89 cm<br>
# M 72-81 cm 89-96 cm<br>
# L 81-93 cm 96-106 cm <br>
# XL 93-101 cm 106-116 cm<br>
# XXL 101-104 cm 116-122 cm

# %%
men_sizes = {"XXS": [(69, 71), (74, 76)], "XS": [(71, 77), (76, 86)], "S": [(77, 81), (86, 97)], "M": [(81, 85), (97, 107)], "L": [(85, 92), (107, 116)], "XL": [(92, 102), (116, 122)], "XXL": [(102, 112), (122, 128)], "3XL": [(112, 122), (128, 132)]}
female_sizes = {"XSS": [(54, 58), (70, 75)], "XS": [(58, 67), (75, 82)], "S": [(67, 72), (82, 89)], "M": [(72, 81), (89, 96)], "L": [(81, 93), (96, 106)], "XL": [(93, 101), (106, 116)], "XXL": [(101, 104), (116, 122)]}

# %%
men_sizes = {"XXS": [71, 76], "XS": [77, 86], "S": [81, 97], "M": [85, 107], "L": [92, 116], "XL": [102, 122], "XXL": [112, 128], "3XL": [122,132]}

# %%
def categories_by_size(df, sizes):
    cloth_sizes = []
    for row in range(df.shape[0]):
        key_found = False
        for key in sizes:
            if all([df[col][row] < sizes[key][i] for i, col in enumerate(df)]):
                cloth_sizes.append(key)
                key_found = True
                break

            if key_found: break

    print(cloth_sizes, "\nLen:", len(cloth_sizes))
    df["clothingsize"] = cloth_sizes
    return df

# %%
#df_male = pd.read_csv('male_sample100.csv')
df_male = categories_by_size(df_male, men_sizes)
print(df_male)
sns.scatterplot(data=df_male, x='chestcircumference', y='waistcircumference', hue='clothingsize')
plt.show()
#backup_sample(df_male, 'male', 100)

#df_female = pd.read_csv('male_sample100.csv')
#df_female = categories_by_size(df, female_sizes)
#backup_sample(df_female, 'female', 100)
# Out:
# ['XXL', 'XXL', '3XL', 'XXL', 'XXL', 'XXL', '3XL', 'XXL', '3XL', 'XL', 'XXL', 'XL', '3XL', 'XXL', 'XXL', 'XXL', 'XXL', 'XL', '3XL', 'XL', 'XL', 'XXL', 'XL', 'XXL', 'XL', '3XL', 'XL', 'XL', 'XXL', 'XL', 'XXL', 'XL', 'XXL', 'XL', '3XL', 'XL', '3XL', 'XL', 'XXL', 'L', '3XL', 'XL', '3XL', 'XXL', 'XL', 'XL', 'XXL', '3XL', 'XXL', '3XL', 'XXL', 'XL', '3XL', 'XXL', 'L', 'XXL', '3XL', 'L', 'XXL', 'L', 'XXL', '3XL', 'XL', 'XXL', '3XL', 'XL', 'XL', 'XL', 'XL', 'XXL', 'XL', '3XL', '3XL', '3XL', '3XL', 'XXL', 'XXL', 'XXL', 'XL', '3XL', 'XL', 'XXL', 'XL', 'XXL', 'XXL', 'L', 'XL', 'XXL', 'XXL', 'L', 'L', 'XL', 'XL', 'XL', 'XXL', 'XL', 'XXL']
# Len: 97
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [98], in <cell line: 2>()
#       1 #df_male = pd.read_csv('male_sample100.csv')
# ----> 2 df_male = categories_by_size(df_male, men_sizes)
#       3 print(df_male)
# ...

# %%
print("="*10 + " Male " + "="*10)
df_male = pd.read_csv('male_sample100.csv')
print(df_male)
print(df_male.columns, '\n')
print(df_male.count())
sns.scatterplot(data=df_male, x='chestcircumference', y='waistcircumference', hue='clothingsize')
plt.show()
# Out:
# ========== Male ==========
#     chestcircumference  waistcircumference
# 0                107.4                93.3
# 1                102.1                87.0
# 2                112.0                96.4
# 3                111.4                85.7
# 4                104.8                86.8
# ..                 ...                 ...
# 95                99.4                80.9
# 96               100.1                86.2
# 97               106.9               102.7
# 98                99.5                79.7
# 99               110.4               108.2
#
# [100 rows x 2 columns]
# Index(['chestcircumference', 'waistcircumference'], dtype='object')
#
# chestcircumference    100
# waistcircumference    100
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 6>()
#       4 print(df_male.columns, '\n')
# ...

# %%
print("="*10 + " Female " + "="*10)
df_female = pd.read_csv('female_sample100.csv')
print(df_female)
print(df_female.columns, '\n')
print(df_female.count())
sns.scatterplot(data=df_female, x='chestcircumference', y='waistcircumference', hue='clothingsize')
plt.show()
# Out:
# ========== Female ==========
#     chestcircumference  waistcircumference
# 0                 92.2                85.0
# 1                 83.9                70.8
# 2                 87.4                72.7
# 3                100.8                92.3
# 4                108.9               116.3
# ..                 ...                 ...
# 95                98.6                94.8
# 96                95.1                91.2
# 97               106.8                98.9
# 98                94.5                88.7
# 99                82.6                69.8
#
# [100 rows x 2 columns]
# Index(['chestcircumference', 'waistcircumference'], dtype='object')
#
# chestcircumference    100
# waistcircumference    100
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 6>()
#       4 print(df_female.columns, '\n')
# ...

# %%
def k_nearest_neighbor(df, P: list, k: int):
    def vec_abs(vec):
        return sqrt(sum([unit**2 for unit in vec]))
    
    def compute_vec(P_1, P_2):
        return [P_1[col] + P_2[col] for col in range(2)]
        

    points = []
    for row in range(df.shape[0]):
        point = [df['chestcircumference'][row], df['waistcircumference'][row]]
        vec = compute_vec(P, point)
        points.append((df['clothingsize'][row] ,vec_abs(vec)))

    cluster = [ size[0] for size in sorted(points, key=lambda y: y[1])[:k]]
    del points
    cluster_point = {i: cluster.count(i) for i in cluster}
    return max(cluster_point, key=cluster_point.get)

# %%
size = k_nearest_neighbor(df, [100, 120], 3) # XL: (92, 102), (116, 122)
print(f"Your predicted clothing size: {size}")
# Out:
# Your predicted clothing size: XXS
